# %%
from vgg16 import Vgg16

# %%
# %matplotlib inline

# %%
vgg = Vgg16()
# Out:
# Downloading data from http://files.fast.ai/models/vgg16.h5
# 552673280/553482496 [============================>.] - ETA: 0sDownloading data from http://files.fast.ai/models/imagenet_class_index.json
# 40960/35363 [==================================] - 0s

# %%
#path = "data/dogscats/"
path = "dogscats/sample/"

# %%
batches = vgg.get_batches(path+'train', batch_size=4)
val_batches = vgg.get_batches(path+'valid', batch_size=64)
# Out:
# Found 160 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
imgs,labels = next(batches)

# %%
import utils; reload(utils)
from utils import plots

# %%
plots(imgs, titles=labels)

# %%
vgg.predict(imgs, True)
# Out:
# (array([ 0.9873,  0.963 ,  0.9922,  1.    ], dtype=float32),
#  array([1, 0, 0, 1]),
#  ['dogs', 'cats', 'cats', 'dogs'])

# %%
vgg.finetune(batches)

# %%
vgg.fit(batches, val_batches, nb_epoch=1)
# Out:
# Epoch 1/1
# 160/160 [==============================] - 5s - loss: 0.0547 - acc: 0.9625 - val_loss: 0.0625 - val_acc: 0.9500
